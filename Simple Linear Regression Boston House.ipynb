# %% [markdown]
# #### Simple Linear Regression on Boston Housing dataset
# * Source blog: https://intellipaat.com/blog/what-is-linear-regression/
# * Source data: https://github.com/selva86/datasets/blob/master/BostonHousing.csv. Save this data as an excel sheet
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# 1. CRIM - per capita crime rate by town
# 2. ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS - proportion of non-retail business acres per town.
# 4. CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5. NOX - nitric oxides concentration (parts per 10 million)
# 6. RM - average number of rooms per dwelling
# 7. AGE - proportion of owner-occupied units built prior to 1940
# 8. DIS - weighted distances to five Boston employment centres
# 9. RAD - index of accessibility to radial highways
# 10. TAX - full-value property-tax rate per USD10,000
# 11. PTRATIO - pupil-teacher ratio by town
# 12. B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT - % lower status of the population
# 14. Target variable: y = MEDV - Median value of owner-occupied homes in USD1000's

# %%
# Step1: use pandas to import the BostonHouse.xlsx dataset
import pandas as pd
# load excel dataset as a Pandas dataframe
house=pd.read_excel("BostonHousing.xlsx")

# Step2: See top few rows of dataset to check
house.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Step3: Explore the dataframe statistics. Get descriptive statistics
house.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# Step 4: Continue exploring by visualizing correlations between variables using matplotlib
import matplotlib.pyplot as plt

# %%
# Draw correlation values with color coding
# Dark colour shows highly correlated values.Blue is positive correlation.
# Light colour shows values that have less correlation. Brown shows negative correlation
correlation = house.corr ()
correlation.style.background_gradient (cmap = 'BrBG')
# Out:
# <style  type="text/css" >
# #T_1af24_row0_col0,#T_1af24_row1_col1,#T_1af24_row2_col2,#T_1af24_row3_col3,#T_1af24_row4_col4,#T_1af24_row5_col5,#T_1af24_row6_col6,#T_1af24_row7_col7,#T_1af24_row8_col8,#T_1af24_row9_col9,#T_1af24_row10_col10,#T_1af24_row11_col11,#T_1af24_row12_col12,#T_1af24_row13_col13{
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }#T_1af24_row0_col1{
#             background-color:  #ca9849;
#             color:  #000000;
#         }#T_1af24_row0_col2{
#             background-color:  #a0dad1;
#             color:  #000000;
#         }#T_1af24_row0_col3{
#             background-color:  #734208;
#             color:  #f1f1f1;
#         }#T_1af24_row0_col4{
#             background-color:  #92d4ca;
#             color:  #000000;
#         }#T_1af24_row0_col5{
#             background-color:  #cd9d50;
#             color:  #000000;
#         }#T_1af24_row0_col6,#T_1af24_row1_col13{
#             background-color:  #b1e1da;
#             color:  #000000;
#         }#T_1af24_row0_col7,#T_1af24_row11_col4,#T_1af24_row11_col10{
#             background-color:  #c58e3d;
#             color:  #000000;
#         }#T_1af24_row0_col8{
#             background-color:  #5bb3a8;
#             color:  #000000;
#         }#T_1af24_row0_col9,#T_1af24_row2_col8,#T_1af24_row8_col0{
#             background-color:  #6abdb2;
#             color:  #000000;
#         }#T_1af24_row0_col10{
#             background-color:  #e7f2f0;
#             color:  #000000;
#         }#T_1af24_row0_col11,#T_1af24_row13_col9{
#             background-color:  #6a3d07;
#             color:  #f1f1f1;
#         }#T_1af24_row0_col12{
#             background-color:  #8ad1c6;
#             color:  #000000;
#         }#T_1af24_row0_col13,#T_1af24_row9_col5{
#             background-color:  #bf812d;
#             color:  #000000;
#         }#T_1af24_row1_col0{
#             background-color:  #9d6116;
#             color:  #000000;
#         }#T_1af24_row1_col2,#T_1af24_row1_col6,#T_1af24_row8_col3{
#             background-color:  #8d520b;
#             color:  #f1f1f1;
#         }#T_1af24_row1_col3{
#             background-color:  #794608;
#             color:  #f1f1f1;
#         }#T_1af24_row1_col4,#T_1af24_row1_col9{
#             background-color:  #a16518;
#             color:  #000000;
#         }#T_1af24_row1_col5,#T_1af24_row2_col0{
#             background-color:  #d4ede9;
#             color:  #000000;
#         }#T_1af24_row1_col7,#T_1af24_row9_col4,#T_1af24_row13_col5{
#             background-color:  #2f9189;
#             color:  #000000;
#         }#T_1af24_row1_col8,#T_1af24_row5_col0{
#             background-color:  #975b12;
#             color:  #f1f1f1;
#         }#T_1af24_row1_col10,#T_1af24_row9_col3,#T_1af24_row13_col8{
#             background-color:  #7e4909;
#             color:  #f1f1f1;
#         }#T_1af24_row1_col11{
#             background-color:  #f6ecd1;
#             color:  #000000;
#         }#T_1af24_row1_col12,#T_1af24_row5_col2,#T_1af24_row6_col3,#T_1af24_row10_col11{
#             background-color:  #b77928;
#             color:  #000000;
#         }#T_1af24_row2_col1,#T_1af24_row7_col3{
#             background-color:  #5f3606;
#             color:  #f1f1f1;
#         }#T_1af24_row2_col3,#T_1af24_row8_col1{
#             background-color:  #ad7021;
#             color:  #000000;
#         }#T_1af24_row2_col4{
#             background-color:  #12766e;
#             color:  #f1f1f1;
#         }#T_1af24_row2_col5,#T_1af24_row7_col12{
#             background-color:  #9f6317;
#             color:  #000000;
#         }#T_1af24_row2_col6{
#             background-color:  #389991;
#             color:  #000000;
#         }#T_1af24_row2_col7,#T_1af24_row4_col1,#T_1af24_row11_col8{
#             background-color:  #663a07;
#             color:  #f1f1f1;
#         }#T_1af24_row2_col9{
#             background-color:  #2b8d85;
#             color:  #000000;
#         }#T_1af24_row2_col10,#T_1af24_row13_col1{
#             background-color:  #cbebe6;
#             color:  #000000;
#         }#T_1af24_row2_col11,#T_1af24_row11_col9,#T_1af24_row12_col3{
#             background-color:  #754308;
#             color:  #f1f1f1;
#         }#T_1af24_row2_col12,#T_1af24_row6_col12,#T_1af24_row12_col6{
#             background-color:  #4aa69d;
#             color:  #000000;
#         }#T_1af24_row2_col13{
#             background-color:  #a3671a;
#             color:  #000000;
#         }#T_1af24_row3_col0{
#             background-color:  #cc9a4c;
#             color:  #000000;
#         }#T_1af24_row3_col1{
#             background-color:  #e7cf94;
#             color:  #000000;
#         }#T_1af24_row3_col2{
#             background-color:  #f5efdc;
#             color:  #000000;
#         }#T_1af24_row3_col4{
#             background-color:  #f5f3ee;
#             color:  #000000;
#         }#T_1af24_row3_col5{
#             background-color:  #f6edd5;
#             color:  #000000;
#         }#T_1af24_row3_col6{
#             background-color:  #f5f2ea;
#             color:  #000000;
#         }#T_1af24_row3_col7{
#             background-color:  #f1dfb3;
#             color:  #000000;
#         }#T_1af24_row3_col8,#T_1af24_row3_col9{
#             background-color:  #e5cc8f;
#             color:  #000000;
#         }#T_1af24_row3_col10{
#             background-color:  #d1a559;
#             color:  #000000;
#         }#T_1af24_row3_col11{
#             background-color:  #e8d29a;
#             color:  #000000;
#         }#T_1af24_row3_col12{
#             background-color:  #f4e5be;
#             color:  #000000;
#         }#T_1af24_row3_col13{
#             background-color:  #e9f2f1;
#             color:  #000000;
#         }#T_1af24_row4_col0,#T_1af24_row12_col10{
#             background-color:  #ceece8;
#             color:  #000000;
#         }#T_1af24_row4_col2{
#             background-color:  #147870;
#             color:  #f1f1f1;
#         }#T_1af24_row4_col3,#T_1af24_row5_col3,#T_1af24_row5_col8{
#             background-color:  #b97b29;
#             color:  #000000;
#         }#T_1af24_row4_col5,#T_1af24_row13_col4{
#             background-color:  #bb7d2a;
#             color:  #000000;
#         }#T_1af24_row4_col6{
#             background-color:  #1d8078;
#             color:  #000000;
#         }#T_1af24_row4_col7,#T_1af24_row6_col1,#T_1af24_row7_col2,#T_1af24_row7_col4,#T_1af24_row7_col6,#T_1af24_row7_col8,#T_1af24_row7_col9,#T_1af24_row8_col11,#T_1af24_row9_col11,#T_1af24_row10_col3,#T_1af24_row11_col0,#T_1af24_row12_col5,#T_1af24_row12_col13,#T_1af24_row13_col0,#T_1af24_row13_col10,#T_1af24_row13_col12{
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }#T_1af24_row4_col8{
#             background-color:  #61b7ac;
#             color:  #000000;
#         }#T_1af24_row4_col9{
#             background-color:  #419f97;
#             color:  #000000;
#         }#T_1af24_row4_col10{
#             background-color:  #f5f0e2;
#             color:  #000000;
#         }#T_1af24_row4_col11{
#             background-color:  #6c3e07;
#             color:  #f1f1f1;
#         }#T_1af24_row4_col12,#T_1af24_row8_col2{
#             background-color:  #4faaa1;
#             color:  #000000;
#         }#T_1af24_row4_col13{
#             background-color:  #b37625;
#             color:  #000000;
#         }#T_1af24_row5_col1{
#             background-color:  #d9eeeb;
#             color:  #000000;
#         }#T_1af24_row5_col4,#T_1af24_row13_col3{
#             background-color:  #d3aa5f;
#             color:  #000000;
#         }#T_1af24_row5_col6{
#             background-color:  #dcbc75;
#             color:  #000000;
#         }#T_1af24_row5_col7{
#             background-color:  #ddefed;
#             color:  #000000;
#         }#T_1af24_row5_col9,#T_1af24_row10_col5{
#             background-color:  #a96c1e;
#             color:  #000000;
#         }#T_1af24_row5_col10,#T_1af24_row12_col1{
#             background-color:  #8b500a;
#             color:  #f1f1f1;
#         }#T_1af24_row5_col11{
#             background-color:  #f5e7c0;
#             color:  #000000;
#         }#T_1af24_row5_col12{
#             background-color:  #7c4709;
#             color:  #f1f1f1;
#         }#T_1af24_row5_col13{
#             background-color:  #278a82;
#             color:  #000000;

# %%
# (Optional) Visualise with a Heat Map which is part of Seaborn library
import seaborn as sns
correlation = house. corr ()  
sns. heatmap (correlation)
# Out:
# <AxesSubplot:>

# %%
# Optional: Explore the distribution and outliers of datasets using boxplot
from scipy import stats

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in house.items():
    sns.boxplot(y=k, data=house, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# Optional : Additional visualizations. Check the linear relation of each variable with y
from sklearn import preprocessing

# Let's scale the columns before plotting them against MEDV
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['lstat', 'indus', 'nox', 'ptratio', 'rm', 'tax', 'dis', 'age']
x = house.loc[:,column_sels]
y = house['medv']
x = pd.DataFrame(data=min_max_scaler.fit_transform(x), columns=column_sels)
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# Optional: Additional exploration of all variables
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in house.items():
    sns.histplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# The histograms above also shows that columns CRIM, ZN, B have highly skewed distributions. Also medv seems to have a normal distribution (the predictions) and other colums seem to have norma or bimodel ditribution of data except CHAS (which is a discrete variable).
#
#
# ##### Start Simple Linear Regression
# Assume House value medv is only dependant on crim ie. per capita crime rate of locality. So the formula we are trying to get is Medv = slope * (crim) + intercept

# %%
# Step 5: Visualise the relation between x & y
house.plot(x='crim',y='medv',style='o')
plt.xlabel('Crime')
plt.ylabel('Medv')
plt.show()

# %%
# Step 6: Extract independant & dependant variables
# Extract x as crim & y as medv dataframes
x= pd.DataFrame(house["crim"])
y= pd.DataFrame(house["medv"])

# %% [markdown]
# ##### Use the Scikit Learn Library (sklearn)
# We will create a training set ie. with 80% of the data to build the model & balance 20% used for testing the model

# %%
# Step 7: Create train & test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
# See the shape ie. Rows x Columns of each train & test dataset
# Remember in the training dataset - both x & y is given to machine to learn the formula
# In the test dataset - only x values are given & machine predicts y with the formula
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
# Step 8: Train the Linear Regression Algorithm with training set
# Note: we are only passing Crim independant variable - simple linear regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Step 9: Retrieve the intercept ie. constant in y=mx+c
print(regressor.intercept_)
# Out:
# [23.95135548]

# %%
# Step 9: Retrieve the slope or coefficient ie. m in y=mx+c.. 
# This is the rate of change of y (medv) per unit change of x (crim)
print(regressor.coef_)
# Out:
# [[-0.38650322]]

# %%
# So the regression equation is: medv = (-0.38650322) * (crim) + 23.95135548
# Step 10: Now use above formula to predict the mdev for the 102 test data set.
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[23.93229314],
#        [23.9415267 ],
#        [23.86274188],
#        [23.92898081],
#        [22.5297116 ],
#        [23.72329925],
#        [23.93738339],
#        [23.42775183],
#        [23.90857344],
#        [23.93325167],
#        [21.74512552],
#        [23.93957099],
#        [23.89540527],
#        [23.9344305 ],
#        [23.85021145],
#        [19.33221683],
#        [18.04249423],
#        [23.74769533],
#        [23.93804044],
#        [23.03587622],
#        [23.85335372],
#        [23.11842171],
#        [23.80865849],
#        [23.81952309],
#        [23.9375032 ],
#        [17.82129843],
#        [23.32799535],
#        [23.93932363],
#        [23.74491638],
#        [20.80068171],
#        [23.92062847],
#        [23.87740582],
#        [23.94359063],
#        [20.11536898],
#        [23.93379277],
#        [23.84330077],
#        [21.52099617],
#        [23.92466743],
#        [15.94447744],
#        [21.75147577],
#        [23.925367  ],
#        [23.93690799],
#        [23.71377195],
#        [21.480394  ],
#        [19.99626801],
#        [19.38586347],
#        [23.24259746],
#        [18.78774974],
#        [22.82122006],
#        [23.862939  ],
#        [22.15531752],
#        [23.9115843 ],
#        [23.93981836],
#        [23.06224347],
#        [23.87117152],
#        [23.90873577],
#        [20.11857696],
#        [23.64585947],
#        [23.64825965],
#        [23.82324125],
#        [19.66603966],
#        [23.92918952],
#        [20.98609503],
#        [20.66911988],
#        [23.83944347],
#        [23.92901559],
#        [23.72900404],
#        [23.94170063],
#        [23.91966608],
#        [23.08467611],
#        [23.83406334],
#        [14.52307319],
#        [22.52247239],
#        [23.56390532],
#        [23.90065785],
#        [22.86204253],
#        [21.42410367],
#        [23.9471194 ],
#        [23.40058066],
#        [23.92087583],
#        [23.82557573],
#        [23.89300122],
#        [23.91900516],
#        [19.63782492],
#        [23.92734976],
#        [23.92636418],
#        [21.04252837],
#        [23.87720097],
#        [23.84762574],
#        [23.73577171],
#        [23.92787154],
#        [23.7149933 ],
#        [23.91048663],
#        [23.91723111],
#        [ 9.3949098 ],
#        [23.90595294],
#        [23.92714878],
#        [23.93511075],
#        [23.82947942],
#        [23.90964018],
#        [19.21777322],
#        [20.09925566]])

# %%
# Step 11: Evaluate the accuracy of the algorithm
# That is calcluate the error of the predicted medv vs. the actual medv of test set.
from sklearn import metrics
import numpy as np
print('Mean Absolute Error: MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Square Error: MSE:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Square Error:RMSE', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: MAE: 6.410754050224137
# Mean Square Error: MSE: 85.36766642411767
# Root Mean Square Error:RMSE 9.239462453201359

# %% [markdown]
# * Lower the MAE score the better. So 6.41 is a good score on a y value of appx 23.
# * Similarly with RMSE (which is easier to interpret than MSE)
